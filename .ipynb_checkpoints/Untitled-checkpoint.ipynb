# %%
from bs4 import BeautifulSoup
import requests

# %%
scraper_session = requests.session()

# %%
url = 'https://www.guru99.com/'

# %%
scraper_session.get(url)
# Out:
# <Response [200]>

# %%
response_soup = BeautifulSoup(scraper_session.get(url).content)

# %%
for i in response_soup.find_all('div'):
    if 'row featured-'i.attrs.get('class')
# Out:
# ['g-grid']
# ['g-block', 'size-100']
# ['g-content', 'g-particle']
#
#
# ['g-offcanvas-hide', 'g-offcanvas-toggle']
# ['g-container']
# ['g-grid']
# ['g-block', 'size-100']
# ['g-system-messages']
#
# ['g-container']
# ['g-grid']
# ['g-block', 'size-20']
# ['g-content', 'g-particle']
# ['g-block', 'size-80']
# ['g-content', 'g-particle']
# ['g-menu-item-container']
# ['g-grid']
# ['g-block', 'size-32']
# ['g-block', 'size-34']
# ['g-block', 'size-34']
# ['g-menu-item-container']
# ['g-grid']
# ['g-block', 'size-30']
# ['g-block', 'size-33']
# ['g-block', 'size-37']
# ['g-menu-item-container']
# ['g-grid']
# ['g-block', 'size-25']
# ['g-block', 'size-24']
# ['g-block', 'size-24']
# ['g-block', 'size-27']
# ['g-menu-item-container']
# ['g-grid']
# ['g-block', 'size-32']
# ['g-block', 'size-33']
# ['g-block', 'size-35']
# ['g-menu-item-container']
# ['g-grid']
# ['g-block', 'size-38']
# ['g-block', 'size-32']
# ['g-block', 'size-30']
# ['g-menu-item-container']
# ['g-grid']
# ['g-block', 'size-50']
# ['g-block', 'size-50']
# ['g-menu-item-container']
# ['g-grid']
# ['g-block', 'size-52']
# ['g-block', 'size-48']
# ['g-menu-item-container']
# ['menu-item-particle']
# ['platform-content']
# ['moduletable']
# ['custom']
#
# ['g-container']
# ['g-grid']
# ['g-block', 'size-100']
# ['g-content']
# ['platform-content']
# ['moduletable']
# ['g-grid']
# ['g-block', 'size-20']
# ['g-block', 'size-60']
# ['g-content', 'g-particle']
# ['srch']
# ['g-block', 'size-20']
# ['g-container']
# ['g-grid']
# ['g-block', 'size-100']
# ['g-content']
# ['platform-content']
# ['moduletable']
# ['row', 'featured-boxes']
# ['col-md-3']
# ['featured-box', 'cloumnsize1']
# ['col-md-3']
# ['featured-box']
# ['col-md-3']
# ['featured-box']
# ['col-md-3']
# ['featured-box']
# ['g-container']
# ['g-grid']
# ['g-block', 'size-100']
# ['g-content']
# ['platform-content']
# ['moduletable']
# ['g-content']
# ['platform-content']
# ['moduletable']
# ['g-grid']
# ['g-block', 'size-100']
# ['platform-content']
# ['moduletable']
# ['g-grid', 'allrotatenativeads1']
# ['g-block', 'box4', 'size-16', 'rotatenativeads1']
# ['g-content', 'g-particle']
# ['canvas-graph']
# ['canvas-middle']
# ['g-block', 'box4', 'size-17', 'rotatenativeads1']
# ['g-content', 'g-particle']
# ['canvas-graph']
# ['canvas-middle']
# ['g-block', 'box4', 'size-17', 'rotatenativeads1']
# ['g-content', 'g-particle']
# ['canvas-graph']
# ['canvas-middle']
# ['g-block', 'box4', 'size-17', 'rotatenativeads1']
# ['g-content', 'g-particle']
# ['canvas-graph']
# ['canvas-middle']
# ['g-block', 'box4', 'size-17', 'hidden-tablet', 'rotatenativeads1']
# ['g-content', 'g-particle']
# ['canvas-graph']
# ['canvas-middle']
# ['g-block', 'box4', 'size-16', 'hidden-tablet', 'rotatenativeads1']
# ['g-content', 'g-particle']
# ['canvas-graph']
# ['canvas-middle']
# ['g-grid']
# ['g-block', 'size-100']
# ['platform-content']
# ['moduletable']
# ['g-grid']
# ['g-block', 'box4', 'size-16']
# ['g-content', 'g-particle']
# ['canvas-graph']
# ['canvas-middle']
# ['g-block', 'box4', 'size-16']
# ['g-content', 'g-particle']
# ['canvas-graph']
# ['canvas-middle']
# ['g-block', 'box4', 'size-17']
# ['g-content', 'g-particle']
# ['canvas-graph']
# ['canvas-middle']
# ['g-block', 'box4', 'size-17']
# ['g-content', 'g-particle']
# ['canvas-graph']
# ['canvas-middle']
# ['g-block', 'box4', 'size-17', 'hidden-tablet']
# ['g-content', 'g-particle']
# ['canvas-graph']
# ['canvas-middle']
# ['g-block', 'box4', 'size-17', 'hidden-tablet']
# ['g-content', 'g-particle']
# ['canvas-graph']
# ['canvas-middle']
# ['g-container']
# ['g-grid']
# ['g-block', 'size-100']
# ['g-content']
# ['platform-content']
# ['moduletable']
# ['g-grid']
# ['g-block', 'size-100']
# ['platform-content']
# ['moduletable']
# ['g-grid']
# ['g-block', 'box4', 'size-30']
# ['g-content', 'g-particle']
# ['g-block', 'box4', 'size-70']
# ['g-content', 'g-particle']
# ['g-grid']
# ['g-block', 'size-100']
# ['g-grid']
# ['g-block', 'size-100']
# ['g-content']
# ['platform-content', 'row-fluid']
# ['span12']
# ['item-page']
#
# ['g-container']
# ['g-grid']
# ['g-block', 'size-100']
# ['g-content']
# ['platform-content']
# ['moduletable']
# ['custom']
# ['g-grid']
# ['g-block', 'size-100', 'hidden-phone']
# ['platform-content']
# ['moduletable']
# ['g-grid']
# ['g-block', 'size-24']
# ['platform-content']
# ['moduletable']
# ['g-block', 'box4', 'size-24', 'hidden-phone']
# ['g-content', 'g-particle']
# ['canvas-graph']
# ['canvas-middle']
# ['g-block', 'box4', 'size-24', 'hidden-phone']
# ['g-content', 'g-particle']
# ['canvas-graph']
# ['canvas-middle']
# ['g-block', 'box4', 'size-24', 'hidden-phone']
# ['g-content', 'g-particle']
# ['canvas-graph']
# ['canvas-middle']
# ['g-grid']
# ['g-block', 'size-24']
# ['platform-content']
# ['moduletable']
# ['g-block', 'box4', 'size-24', 'hidden-phone']
# ['g-content', 'g-particle']
# ['canvas-graph']
# ['canvas-middle']
# ['g-block', 'box4', 'size-24', 'hidden-phone']
# ['g-content', 'g-particle']
# ['canvas-graph']
# ['canvas-middle']
# ['g-block', 'box4', 'size-24', 'hidden-phone']
# ['g-content', 'g-particle']
# ['canvas-graph']
# ['canvas-middle']
# ['g-grid', 'execute_online']
# ['g-block', 'size-24']
# ['platform-content']
# ['moduletable']
# ['g-block', 'size-24', 'hidden-phone']
# ['g-content', 'g-particle']
# ['canvas-graph']
# ['canvas-middle']
# ['g-block', 'size-24', 'hidden-phone']
# ['g-content', 'g-particle']
# ['canvas-graph']
# ['canvas-middle']
# ['g-block', 'size-24', 'hidden-phone']
# ['g-content', 'g-particle']
# ['canvas-graph']
# ['canvas-middle']
# ['g-grid']
# ['g-block', 'size-50', 'align-left']
# ['g-content', 'g-particle']
# ['g-branding']
# ['brackbranding']
# ['g-block', 'size-50']
# ['spacer']

# %%
test = response_soup.find_all('div')

# %%
test[0].attrs.get('class','')
# Out:
# ''
